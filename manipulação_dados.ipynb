# %% [markdown]
# <a href="https://colab.research.google.com/github/Vasquez-Alex/Manipulando-dados-com-pandas/blob/main/manipula%C3%A7%C3%A3o_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

dados = {
    'Produtos': ['A', 'B', 'C', 'D'],
    'Valor': [50, 120, 180, 250],
    'Quantidade': [10, 100, 1000, 500]
}

df  = pd.DataFrame(dados)

filtro = df[df['Valor'] > 150]
print("/n os valores maiores que 150 são:" )
filtro
# Out:
# /n os valores maiores que 150 são:
#   Produtos  Valor  Quantidade
# 2        C    180        1000
# 3        D    250         500

# %%
filtro3 = df[(df['Valor'] > 150) & (df['Quantidade'] > 10)]
print("\n Linhas com valor > 150 e Quantidade > 10 são:")
filtro3
# Out:
#  Linhas com valor > 150 e Quantidade > 10 são:
#   Produtos  Valor  Quantidade
# 2        C    180        1000
# 3        D    250         500

# %%
filtro2 = df[df['Produtos'].isin(['A', 'B'])]
print("/n os  valores que tem A ou B são:" )
filtro2
# Out:
# /n os  valores que tem A ou B são:
#   Produtos  Valor  Quantidade
# 0        A     50          10
# 1        B    120         100
